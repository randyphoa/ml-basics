# %%
import importlib
import pandas as pd
import utils

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/randyphoa/Dropbox/projects/ml-basics/notebook/utils.py'>

# %%
df = utils.get_product_propensity_data()

df
# Out:
#      Customer_ID  Age Gender  Credit_Limit Transaction_Source  \
# 0              1   52      M         43543                  M
# 1              2   55      F        104464                  P
# 2              3   47      M         73627                  M
# 3              4   19      M         91151                  U
# 4              5   54      F        120060                  D
# ..           ...  ...    ...           ...                ...
# 995          996   50      M        147794                  V
# 996          997   28      F        112856                  U
# 997          998   53      F         48702                  M
# 998          999   44      F        118374                  A
# 999         1000   44      F         66356                  P
#
#      Transaction_Type  Avg_Transaction_Value  Customer_Segment  Purchase
# 0                   2             472.394263                 2         1
# 1                   4             373.486860                 1         1
# ...
