# %%
import importlib
import pandas as pd
import utils

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/nicolearitranair/ml-basics/notebook/utils.py'>

# %%
df = utils.get_product_propensity_data()

df
# Out:
#      Customer_ID  Age Gender  Credit_Limit  Transaction_Source_M_Count  \
# 0              1   64      M         68670                           0
# 1              2   32      M         86984                           1
# 2              3   60      F        147812                           0
# 3              4   51      F         25789                           0
# 4              5   41      F         30436                           1
# ..           ...  ...    ...           ...                         ...
# 995          996   32      F        123213                           0
# 996          997   35      F         73376                           0
# 997          998   37      F         59882                           1
# 998          999   56      F         94036                           0
# 999         1000   66      F         80213                           0
#
#      Transaction_Source_A_Count  Transaction_Source_D_Count  \
# ...

# %%
df.to_csv("output_data/product-propensity.csv")
