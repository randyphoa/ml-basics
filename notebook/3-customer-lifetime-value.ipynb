# %%
import importlib
import pandas as pd
import utils

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/nicolearitranair/ml-basics/notebook/utils.py'>

# %%
df = utils.get_cltv_data()

df
# Out:
#      Customer_ID  Age Gender  CreditScore  Tenure        Balance  \
# 0              1   24      M          571       0   54889.095180
# 1              2   50      M          703       0    3149.957509
# 2              3   55      M          475       8   76112.818834
# 3              4   62      M          516       4  184185.781445
# 4              5   26      M          364       3  158107.949954
# ..           ...  ...    ...          ...     ...            ...
# 995          996   29      F          571       9   22779.828120
# 996          997   34      M          843       9   67087.354122
# 997          998   37      M          540       6   61893.667196
# 998          999   28      F          529       5  185907.568996
# 999         1000   24      F          467       6  163133.842782
#
#      NumOfProducts Country  HasCrCard  Transaction_Source_M_Count  \
# 0                1      AE          0                           0
# ...

# %%
df.to_csv("output_data/customer-lifetime-value.csv")
